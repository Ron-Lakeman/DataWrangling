# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 100)

# %%
data = pd.read_csv('SES-WOA Score (CBS)/SESWOA_scores.csv', delimiter = ',')
SESWOA_scores = pd.DataFrame(data)

data = pd.read_csv('Housing Prices (CBS)/housing_price.csv', delimiter = ';')
housing_prices = pd.DataFrame(data)

# %%
SESWOA_scores_gemeente_only = SESWOA_scores[SESWOA_scores['Region_Code'].str.startswith('GM')]

# %%
SESWOA_and_avg_Housing_price = pd.merge(
    SESWOA_scores_gemeente_only,
    housing_prices,
    left_on=['Region_Code', 'Periode'],
    right_on=['RegioS', 'Perioden'],
    how='inner'
)
SESWOA_and_avg_Housing_price
# Out:
#        index   Periode SES-Score Spreiding       Plaats Buurt Wijk  \
# 0          0  2014JJ00     0,141     0,701  Aa en Hunze   NaN  NaN
# 1          2  2015JJ00     0,144     0,701  Aa en Hunze   NaN  NaN
# 2          4  2016JJ00     0,146     0,703  Aa en Hunze   NaN  NaN
# 3          6  2017JJ00     0,137     0,715  Aa en Hunze   NaN  NaN
# 4          8  2018JJ00     0,136      0,72  Aa en Hunze   NaN  NaN
# ...      ...       ...       ...       ...          ...   ...  ...
# 2107  153724  2015JJ00     0,006      0,87       Zwolle   NaN  NaN
# 2108  153726  2016JJ00         0     0,882       Zwolle   NaN  NaN
# 2109  153728  2017JJ00    -0,006     0,892       Zwolle   NaN  NaN
# 2110  153730  2018JJ00    -0,005     0,894       Zwolle   NaN  NaN
# 2111  153732  2019JJ00     0,008     0,884       Zwolle   NaN  NaN
#
#          Gemeente Region_Code               Region_Description     ID  RegioS  \
# 0     Aa en Hunze      GM1680  Gemeente 'Aa en Hunze' (GM1680)    512  GM1680
# ...

# %%
SESWOA_and_avg_Housing_price.to_csv('SESWOA_and_avg_Housing_price.csv', index = False)
